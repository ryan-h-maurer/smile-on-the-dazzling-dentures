# %%
import pandas as pd

# %% [raw]
# smile = pd.read_csv('C:/Users/6106057/nss-data-analytics/projects/smile-on-the-dazzling-dentures/Data/Smileon.2021.10.17.csv')

# %% [raw]
# smile.head()

# %% [raw]
# smile.columns

# %%
def convert_dtype(x):
    if not x:
        return ''
    try:
        return str(x)
    except:
        return ''
def convert_dtypea(x):
    if not x:
        return ''
    try:
        return int(x)
    except:
        return ''
smile = pd.read_csv('C:/Users/6106057/nss-data-analytics/projects/smile-on-the-dazzling-dentures/Data/Smileon.2021.10.17.csv', skiprows=2, header=0, encoding='latin-1', converters={
    'LinkedToCallReportNum':convert_dtype, 'ThirdPartyStateProvince':convert_dtype, 'FeedbackFromPhoneWorkerName':convert_dtype,
'SMILE ON 60+ Demographic Information - # of People in Household':convert_dtypea, 'Birth Year':convert_dtypea, 'SMILE ON 60+ Oral Care Encounter - 2393 - Quantity':convert_dtypea,
'SMILE ON 60+ Oral Care Encounter - 2950 - Quantity':convert_dtypea, 'SMILE ON 60+ Oral Care Encounter - 4342 - Quantity':convert_dtypea,
'SMILE ON 60+ Oral Care Encounter - 7140 - Quantity':convert_dtypea, 'SMILE ON 60+ Oral Care Encounter - 7320 - Quantity':convert_dtypea,
'SMILE ON 60+ Oral Care Encounter - Lab Assist narrative':convert_dtype, 'SMILE ON 60+ Case Management Information - What is the outcome for the client?':convert_dtype,
'SMILE ON 60+ Case Management Information - Dental Clinic':convert_dtype})
# Out:
# C:\Users\6106057\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (36,59) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
smile.head(15)+t
# Out:
#     CallReportNum              ReportVersion LinkedToCallReportNum  \
# 0        93115324  SMILE ON 60+ Registration
# 1        93115188  SMILE ON 60+ Registration
# 2        93115081      SMILE ON 60+ Clinical
# 3        93115032      SMILE ON 60+ Clinical
# 4        93114968      SMILE ON 60+ Clinical
# 5        93114880  SMILE ON 60+ Registration
# 6        93114808  SMILE ON 60+ Registration
# 7        93114741  SMILE ON 60+ Registration
# 8        93114520      SMILE ON 60+ Clinical
# 9        93154018      SMILE ON 60+ Clinical
# 10       93292560      SMILE ON 60+ Clinical
# 11       93292005      SMILE ON 60+ Clinical
# 12       93336535      SMILE ON 60+ Clinical
# 13       93336377      SMILE ON 60+ Clinical
# 14       93336162      SMILE ON 60+ Clinical
#
#    CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum  \
# 0       9/30/2021 16:56    9/30/2021 16:57           1    3638169
# 1       9/30/2021 16:53    9/30/2021 16:53           0    4431194
# ...

# %%
smile.dtypes
# Out:
# CallReportNum                                                                                                                                                               int64
# ReportVersion                                                                                                                                                              object
# LinkedToCallReportNum                                                                                                                                                      object
# CallDateAndTimeStart                                                                                                                                                       object
# CallDateAndTimeEnd                                                                                                                                                         object
# ...

# %% [markdown]
# # some of columns don't have value, need to drop

# %%
smile_gender = smile[smile.columns[smile.columns.isin(['SMILE ON 60+ Demographic Information - Gender'])]]
smile_gender.isnull
# Out:
# <bound method DataFrame.isnull of       SMILE ON 60+ Demographic Information - Gender
# 0                                            Female
# 1                                            Female
# 2                                              Male
# 3                                              Male
# 4                                            Female
# ...                                             ...
# 57855                                        Female
# 57856                                        Female
# 57857                                           NaN
# 57858                                          Male
# 57859                                        Female
#
# [57860 rows x 1 columns]>

# %% [markdown]
# # this is just gender counts.

# %%
gender_counts = smile_gender.value_counts()
print(gender_counts)
# Out:
# SMILE ON 60+ Demographic Information - Gender
# Female                                           35855
# Male                                             21462
# Transgender                                         21
# Other                                                1
# dtype: int64

# %%
gender_counts = gender_counts.reset_index()
gender_counts = gender.rename(columns ={'SMILE ON 60+ Demographic Information - Gender':'Gender', '0':'numbers'})
gender_counts.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8ffc04920c52> in <module>
#       1 gender_counts = gender_counts.reset_index()
# ----> 2 gender_counts = gender.rename(columns ={'SMILE ON 60+ Demographic Information - Gender':'Gender', '0':'numbers'})
#       3 gender_counts.info()
#
# NameError: name 'gender' is not defined

# %%
gender_counts['Numbers'] = gender_counts['Numbers'].astype(int)
gender_counts.info()

# %%
import matplotlib.pyplot as plt
plt.bar('Gender','Numbers', data = gender_counts)
plt.xticks(rotation = 100)

plt.title('Demographic Information - Gender');

# %% [markdown]
# # Add more conditions for gender counts.

# %%
smile_on.columns = smile_on.columns.str.replace(r'SMILE ON 60\+ ', '')
smile_on.columns = smile_on.columns.str.replace('Oral Care Encounter - ', 'oec_')
smile_on.columns = smile_on.columns.str.replace(' - Quantity', '')
